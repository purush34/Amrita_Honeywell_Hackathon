# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation
from tensorflow.keras.optimizers import Adam

# %%
x_train = pd.read_csv("Dataset2/Train/Voltage_L1_train.csv")
y_train = pd.read_csv("Dataset2/Train/output_train.csv")
x_test = pd.read_csv("Dataset2/Test/Voltage_L1_test.csv")
y_test = pd.read_csv("Dataset2/Test/output_test.csv")

# %%
print("x_train",x_train.shape)
print("y_train",y_train.shape)
print("x_test",x_test.shape)
print("y_test",y_test.shape)
# Out:
# x_train (5999, 256)
# y_train (5999, 1)
# x_test (3599, 256)
# y_test (3599, 1)

# %%
x_train.dropna(axis=0,inplace=True)
y_train.dropna(axis=0,inplace=True)
x_test.dropna(axis=0,inplace=True)
y_test.dropna(axis=0,inplace=True)

# %%
print("x_train",x_train.shape)
print("y_train",y_train.shape)
print("x_test",x_test.shape)
print("y_test",y_test.shape)
# Out:
# x_train (5999, 256)
# y_train (5999, 1)
# x_test (3599, 256)
# y_test (3599, 1)

# %%
header =[]
for i in range(1,x_train.shape[1]+1):
    header.append("Col"+str(i))

# %%
x_train.columns = header
x_test.columns = header

# %%
header = ["output"]
y_train.columns = header
y_test.columns = header

# %%
x_train.head()
# Out:
#           Col1         Col2         Col3         Col4         Col5  \
# 0   573.652486  1003.343736  1588.404525  2317.576741  2804.364311
# 1  4757.365183  5264.598912  5428.642486  5650.413073  5939.710012
# 2  4242.144824  4644.679402  5013.356532  5229.417051  5534.898007
# 3  2077.819247  2561.679246  3085.653813  3545.905160  4023.421592
# 4  3599.645319  4099.944762  4499.282469  4897.875855  5120.077118
#
#           Col6         Col7         Col8         Col9        Col10  ...  \
# 0  3225.322510  3662.821690  4174.627969  4656.244143  4939.070130  ...
# 1  5911.948067  6147.642171  6076.921501  5958.797444  6053.817701  ...
# 2  5797.190678  5930.658682  5960.014599  6055.336310  6103.707793  ...
# 3  4496.705157  4809.079868  5186.298840  5453.627533  5737.354699  ...
# 4  5402.227743  5694.801362  5928.683099  5981.616502  6052.006904  ...
#
#         Col247       Col248       Col249       Col250       Col251  \
# 0 -4650.282434 -4228.581226 -3865.609932 -3395.654756 -2933.680470
# 1  -280.360872   323.325836   861.103019  1415.929276  2007.692919
# 2 -1256.270585  -616.527428   -67.068193   549.016676  1099.652199
# 3 -3557.345152 -3017.951179 -2596.647329 -1996.266675 -1467.203661
# 4 -2020.240712 -1388.704968  -849.731284  -232.632694   341.406093
#
#         Col252       Col253       Col254       Col255       Col256
# 0 -2322.450904 -1841.562453 -1282.042025  -601.968217  -156.848367
# 1  2561.130303  2960.282598  3619.932691  4008.288701  4422.229911
# 2  1697.572166  2239.961604  2776.876479  3248.638662  3807.665149
# 3  -885.101101  -329.685256   304.222722   935.528504  1460.127297
# 4   854.579135  1528.023058  2002.557438  2576.468343  3036.303600
#
# [5 rows x 256 columns]

# %%
x_test.head()
# Out:
#           Col1         Col2         Col3         Col4         Col5  \
# 0  4216.164293  4550.919227  4885.253969  5265.577080  5634.058181
# 1   795.638794  1340.736614  1928.805243  2465.916079  3009.942949
# 2  1220.943267  1770.550513  2318.816674  2850.186275  3357.786987
# 3  1013.772210  1621.783618  2178.146635  2733.460484  3178.151416
# 4  4490.355896  4862.601717  5235.681699  5401.432840  5741.255908
#
#           Col6         Col7         Col8         Col9        Col10  ...  \
# 0  5690.878844  5984.805444  6083.124480  6024.018340  6144.339029  ...
# 1  3475.153730  3938.568022  4372.781654  4765.603003  5090.817748  ...
# 2  3848.017230  4274.339651  4669.175893  5027.840955  5329.856655  ...
# 3  3692.797702  4177.895304  4539.640464  4948.873847  5271.862849  ...
# 4  5840.507807  6030.352157  6037.480783  6109.355580  6000.190091  ...
#
#         Col247       Col248       Col249       Col250       Col251  \
# 0 -1279.720481  -672.204610   -35.247405   565.001817  1139.580709
# 1 -4525.083123 -4077.498908 -3630.262875 -3176.648183 -2652.563485
# 2 -4214.790563 -3762.024055 -3303.182589 -2802.950592 -2246.516780
# 3 -4371.401183 -3937.075334 -3502.317297 -2922.179500 -2467.320667
# 4  -848.410798  -279.507713   269.777288   853.806015  1410.187144
#
#         Col252       Col253       Col254       Col255       Col256
# 0  1623.258946  2159.189259  2729.066018  3292.437301  3770.985050
# 1 -2135.982927 -1549.968773  -970.063115  -413.973048   202.507328
# 2 -1712.153266 -1120.729328  -553.276475    43.863168   614.870963
# 3 -1904.033355 -1362.385474  -704.032900  -188.518269   466.064827
# 4  1977.999116  2621.735468  3069.781180  3624.993700  4116.325633
#
# [5 rows x 256 columns]

# %%
y_train.head()
# Out:
#    output
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
y_test.head()
# Out:
#    output
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
from sklearn.model_selection import train_test_split
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.20, random_state=42)

# %%
print('x_train',x_train.shape)
print('y_train',y_train.shape)
print('x_val',x_val.shape)
print('y_val',y_val.shape)
print('x_test',x_test.shape)
print('y_test',y_test.shape)
# Out:
# x_train (4799, 256)
# y_train (4799, 1)
# x_val (1200, 256)
# y_val (1200, 1)
# x_test (3599, 256)
# y_test (3599, 1)

# %%
y_train_hot = pd.get_dummies(y_train['output'])
y_test_hot = pd.get_dummies(y_test['output'])
y_val_hot = pd.get_dummies(y_val['output'])

# %%
y_train_hot.head()
# Out:
#       1  2  3  4  5  6
# 5627  0  0  0  0  0  1
# 1755  0  1  0  0  0  0
# 2344  0  0  1  0  0  0
# 4283  0  0  0  0  1  0
# 3034  0  0  0  1  0  0

# %%
y_train_arr = y_train_hot.to_numpy()
y_test_arr = y_test_hot.to_numpy()
y_val_arr = y_val_hot.to_numpy()
print("y_train:",y_train_arr.shape)
print("y_test:",y_test_arr.shape)
print("y_val:",y_val_arr.shape)
# Out:
# y_train: (4799, 6)
# y_test: (3599, 6)
# y_val: (1200, 6)

# %%
transform = StandardScaler()
x_train_tr = transform.fit_transform(x_train)
x_test_tr = transform.fit_transform(x_test)
x_val_tr = transform.fit_transform(x_val)

# %%
print("Training",x_train_tr.shape)
print(y_train_arr.shape)
print("Validation",x_val_tr.shape)
print(y_val_arr.shape)
print("Test",x_test_tr.shape)
print(y_test_arr.shape)
# Out:
# Training (4799, 256)
# (4799, 6)
# Validation (1200, 256)
# (1200, 6)
# Test (3599, 256)
# (3599, 6)

# %%
model = Sequential()

model.add(Dense(256, input_shape=(256,), activation = 'relu'))

model.add(Dense(256, activation = 'relu'))
model.add(Dropout(0.6))

model.add(Dense(128, activation = 'relu'))
model.add(Dropout(0.5))

model.add(Dense(6, activation = 'softmax'))

model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
history = model.fit(x_train_tr, y_train_arr, batch_size=64, epochs=30, validation_data=(x_val_tr, y_val_arr))
# Out:
# Epoch 1/30
# 75/75 [==============================] - 0s 4ms/step - loss: 0.8930 - accuracy: 0.6741 - val_loss: 0.2343 - val_accuracy: 0.8692
# Epoch 2/30
# 75/75 [==============================] - 0s 3ms/step - loss: 0.2949 - accuracy: 0.8439 - val_loss: 0.2234 - val_accuracy: 0.8817
# Epoch 3/30
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2579 - accuracy: 0.8502 - val_loss: 0.2132 - val_accuracy: 0.8942
# Epoch 4/30
# 75/75 [==============================] - 0s 3ms/step - loss: 0.2410 - accuracy: 0.8614 - val_loss: 0.2132 - val_accuracy: 0.8508
# Epoch 5/30
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2154 - accuracy: 0.8816 - val_loss: 0.1900 - val_accuracy: 0.8967
# Epoch 6/30
# 75/75 [==============================] - 0s 3ms/step - loss: 0.2118 - accuracy: 0.8883 - val_loss: 0.1950 - val_accuracy: 0.9000
# Epoch 7/30
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2055 - accuracy: 0.8862 - val_loss: 0.1910 - val_accuracy: 0.9033
# Epoch 8/30
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1993 - accuracy: 0.8941 - val_loss: 0.1889 - val_accuracy: 0.8992
# Epoch 9/30
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1907 - accuracy: 0.8983 - val_loss: 0.1897 - val_accuracy: 0.9042
# Epoch 10/30
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1857 - accuracy: 0.9112 - val_loss: 0.1856 - val_accuracy: 0.8975
# Epoch 11/30
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2589 - accuracy: 0.8802 - val_loss: 0.1947 - val_accuracy: 0.9058
# Epoch 12/30
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1992 - accuracy: 0.8964 - val_loss: 0.1837 - val_accuracy: 0.9225
# Epoch 13/30
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1804 - accuracy: 0.9052 - val_loss: 0.1803 - val_accuracy: 0.9092
# Epoch 14/30
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1686 - accuracy: 0.9141 - val_loss: 0.1633 - val_accuracy: 0.9217
# Epoch 15/30
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1655 - accuracy: 0.9181 - val_loss: 0.1656 - val_accuracy: 0.9225
# Epoch 16/30
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1571 - accuracy: 0.9260 - val_loss: 0.1557 - val_accuracy: 0.9192
# Epoch 17/30
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1669 - accuracy: 0.9160 - val_loss: 0.1710 - val_accuracy: 0.9150
# Epoch 18/30
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1709 - accuracy: 0.9131 - val_loss: 0.1746 - val_accuracy: 0.9175
# Epoch 19/30
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1916 - accuracy: 0.9081 - val_loss: 0.1703 - val_accuracy: 0.9150
# Epoch 20/30
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1903 - accuracy: 0.9071 - val_loss: 0.1710 - val_accuracy: 0.9133
# Epoch 21/30
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1662 - accuracy: 0.9242 - val_loss: 0.1414 - val_accuracy: 0.9383
# Epoch 22/30
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1433 - accuracy: 0.9331 - val_loss: 0.1381 - val_accuracy: 0.9500
# Epoch 23/30
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1574 - accuracy: 0.9235 - val_loss: 0.1697 - val_accuracy: 0.9158
# Epoch 24/30
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1466 - accuracy: 0.9300 - val_loss: 0.1465 - val_accuracy: 0.9342
# Epoch 25/30
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1268 - accuracy: 0.9433 - val_loss: 0.1518 - val_accuracy: 0.9325
# Epoch 26/30
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1580 - accuracy: 0.9267 - val_loss: 0.1402 - val_accuracy: 0.9442
# Epoch 27/30
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1581 - accuracy: 0.9304 - val_loss: 0.2423 - val_accuracy: 0.8800
# Epoch 28/30
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1645 - accuracy: 0.9271 - val_loss: 0.1600 - val_accuracy: 0.9208
# Epoch 29/30
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1363 - accuracy: 0.9367 - val_loss: 0.1629 - val_accuracy: 0.9175
# Epoch 30/30
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1424 - accuracy: 0.9300 - val_loss: 0.1541 - val_accuracy: 0.9258

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_8 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 6)                 774
# =================================================================
# Total params: 165,254
# Trainable params: 165,254
# Non-trainable params: 0
# _________________________________________________________________

# %%
pred_acc = model.evaluate(x_test_tr,y_test_arr)
print("Test accuracy is {}".format(pred_acc))
# Out:
# 113/113 [==============================] - 0s 975us/step - loss: 0.1458 - accuracy: 0.9264
# Test accuracy is [0.14578446745872498, 0.9263684153556824]
