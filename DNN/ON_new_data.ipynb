# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.fft import fft,fftfreq
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation
from tensorflow.keras.optimizers import Adam

# %%
x_train = pd.read_csv("../Dataset2/Train/Voltage_L1_train.csv")
y_train = pd.read_csv("../Dataset2/Train/output_train.csv")
x_test = pd.read_csv("../Dataset2/Test/Voltage_L1_test.csv")
y_test = pd.read_csv("../Dataset2/Test/output_test.csv")

# %%
print("x_train",x_train.shape)
print("y_train",y_train.shape)
print("x_test",x_test.shape)
print("y_test",y_test.shape)
# Out:
# x_train (5999, 256)
# y_train (5999, 1)
# x_test (3599, 256)
# y_test (3599, 1)

# %%
x_train.dropna(axis=0,inplace=True)
y_train.dropna(axis=0,inplace=True)
x_test.dropna(axis=0,inplace=True)
y_test.dropna(axis=0,inplace=True)

# %%
print("x_train",x_train.shape)
print("y_train",y_train.shape)
print("x_test",x_test.shape)
print("y_test",y_test.shape)
# Out:
# x_train (5999, 256)
# y_train (5999, 1)
# x_test (3599, 256)
# y_test (3599, 1)

# %%
header =[]
for i in range(1,x_train.shape[1]+1):
    header.append("Col"+str(i))

# %%
x_train.columns = header
x_test.columns = header

# %%
header = ["output"]
y_train.columns = header
y_test.columns = header

# %%
x_train.head()
# Out:
#           Col1         Col2         Col3         Col4         Col5  \
# 0   573.652486  1003.343736  1588.404525  2317.576741  2804.364311
# 1  4757.365183  5264.598912  5428.642486  5650.413073  5939.710012
# 2  4242.144824  4644.679402  5013.356532  5229.417051  5534.898007
# 3  2077.819247  2561.679246  3085.653813  3545.905160  4023.421592
# 4  3599.645319  4099.944762  4499.282469  4897.875855  5120.077118
#
#           Col6         Col7         Col8         Col9        Col10  ...  \
# 0  3225.322510  3662.821690  4174.627969  4656.244143  4939.070130  ...
# 1  5911.948067  6147.642171  6076.921501  5958.797444  6053.817701  ...
# 2  5797.190678  5930.658682  5960.014599  6055.336310  6103.707793  ...
# 3  4496.705157  4809.079868  5186.298840  5453.627533  5737.354699  ...
# 4  5402.227743  5694.801362  5928.683099  5981.616502  6052.006904  ...
#
#         Col247       Col248       Col249       Col250       Col251  \
# 0 -4650.282434 -4228.581226 -3865.609932 -3395.654756 -2933.680470
# 1  -280.360872   323.325836   861.103019  1415.929276  2007.692919
# 2 -1256.270585  -616.527428   -67.068193   549.016676  1099.652199
# 3 -3557.345152 -3017.951179 -2596.647329 -1996.266675 -1467.203661
# 4 -2020.240712 -1388.704968  -849.731284  -232.632694   341.406093
#
#         Col252       Col253       Col254       Col255       Col256
# 0 -2322.450904 -1841.562453 -1282.042025  -601.968217  -156.848367
# 1  2561.130303  2960.282598  3619.932691  4008.288701  4422.229911
# 2  1697.572166  2239.961604  2776.876479  3248.638662  3807.665149
# 3  -885.101101  -329.685256   304.222722   935.528504  1460.127297
# 4   854.579135  1528.023058  2002.557438  2576.468343  3036.303600
#
# [5 rows x 256 columns]

# %%
x_test.head()
# Out:
#           Col1         Col2         Col3         Col4         Col5  \
# 0  4216.164293  4550.919227  4885.253969  5265.577080  5634.058181
# 1   795.638794  1340.736614  1928.805243  2465.916079  3009.942949
# 2  1220.943267  1770.550513  2318.816674  2850.186275  3357.786987
# 3  1013.772210  1621.783618  2178.146635  2733.460484  3178.151416
# 4  4490.355896  4862.601717  5235.681699  5401.432840  5741.255908
#
#           Col6         Col7         Col8         Col9        Col10  ...  \
# 0  5690.878844  5984.805444  6083.124480  6024.018340  6144.339029  ...
# 1  3475.153730  3938.568022  4372.781654  4765.603003  5090.817748  ...
# 2  3848.017230  4274.339651  4669.175893  5027.840955  5329.856655  ...
# 3  3692.797702  4177.895304  4539.640464  4948.873847  5271.862849  ...
# 4  5840.507807  6030.352157  6037.480783  6109.355580  6000.190091  ...
#
#         Col247       Col248       Col249       Col250       Col251  \
# 0 -1279.720481  -672.204610   -35.247405   565.001817  1139.580709
# 1 -4525.083123 -4077.498908 -3630.262875 -3176.648183 -2652.563485
# 2 -4214.790563 -3762.024055 -3303.182589 -2802.950592 -2246.516780
# 3 -4371.401183 -3937.075334 -3502.317297 -2922.179500 -2467.320667
# 4  -848.410798  -279.507713   269.777288   853.806015  1410.187144
#
#         Col252       Col253       Col254       Col255       Col256
# 0  1623.258946  2159.189259  2729.066018  3292.437301  3770.985050
# 1 -2135.982927 -1549.968773  -970.063115  -413.973048   202.507328
# 2 -1712.153266 -1120.729328  -553.276475    43.863168   614.870963
# 3 -1904.033355 -1362.385474  -704.032900  -188.518269   466.064827
# 4  1977.999116  2621.735468  3069.781180  3624.993700  4116.325633
#
# [5 rows x 256 columns]

# %%
y_train.head()
# Out:
#    output
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
y_test.head()
# Out:
#    output
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
from sklearn.model_selection import train_test_split
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.20, random_state=42)

# %%
print('x_train',x_train.shape)
print('y_train',y_train.shape)
print('x_val',x_val.shape)
print('y_val',y_val.shape)
print('x_test',x_test.shape)
print('y_test',y_test.shape)
# Out:
# x_train (4799, 256)
# y_train (4799, 1)
# x_val (1200, 256)
# y_val (1200, 1)
# x_test (3599, 256)
# y_test (3599, 1)

# %%
y_train_hot = pd.get_dummies(y_train['output'])
y_test_hot = pd.get_dummies(y_test['output'])
y_val_hot = pd.get_dummies(y_val['output'])

# %%
y_train_hot.head()
# Out:
#       1  2  3  4  5  6
# 5627  0  0  0  0  0  1
# 1755  0  1  0  0  0  0
# 2344  0  0  1  0  0  0
# 4283  0  0  0  0  1  0
# 3034  0  0  0  1  0  0

# %%
y_train_arr = y_train_hot.to_numpy()
y_test_arr = y_test_hot.to_numpy()
y_val_arr = y_val_hot.to_numpy()
print("y_train:",y_train_arr.shape)
print("y_test:",y_test_arr.shape)
print("y_val:",y_val_arr.shape)
no_of_classes = y_train_arr.shape[1]
#print(no_of_classes)
# Out:
# y_train: (4799, 6)
# y_test: (3599, 6)
# y_val: (1200, 6)

# %%
x_train = x_train.to_numpy()
x_test = x_test.to_numpy()
x_val = x_val.to_numpy()
for i in range(0,x_train.shape[0]):
    x_train[i][0:128] = fft(x_train[i][0:128])
    
for i in range(0,x_test.shape[0]):
    x_test[i][0:128] = fft(x_test[i][0:128])

for i in range(0,x_val.shape[0]):
    x_val[i][0:128] = fft(x_val[i][0:128])
# Out:
# <ipython-input-97-8c3a30f65815>:5: ComplexWarning: Casting complex values to real discards the imaginary part
#   x_train[i][0:128] = fft(x_train[i][0:128])
# <ipython-input-97-8c3a30f65815>:8: ComplexWarning: Casting complex values to real discards the imaginary part
#   x_test[i][0:128] = fft(x_test[i][0:128])
# <ipython-input-97-8c3a30f65815>:11: ComplexWarning: Casting complex values to real discards the imaginary part
#   x_val[i][0:128] = fft(x_val[i][0:128])

# %%
transform = StandardScaler()
x_train_tr = transform.fit_transform(x_train)
x_test_tr = transform.fit_transform(x_test)
x_val_tr = transform.fit_transform(x_val)

# %%
print("Training",x_train_tr.shape)
print(y_train_arr.shape)
print("Validation",x_val_tr.shape)
print(y_val_arr.shape)
print("Test",x_test_tr.shape)
print(y_test_arr.shape)
sampling_rate = x_train_tr.shape[1]
# Out:
# Training (4799, 256)
# (4799, 6)
# Validation (1200, 256)
# (1200, 6)
# Test (3599, 256)
# (3599, 6)

# %%
def model_training(no_of_classes,sampling_rate):
    model = Sequential()

    model.add(Dense(64, input_shape=(sampling_rate,), activation = 'relu'))

    #model.add(Dense(64, activation = 'relu'))
    #model.add(Dense(64, activation = 'relu'))
    #model.add(Dropout(0.6))

    #model.add(Dense(64, activation = 'relu'))
    #model.add(Dropout(0.6))

    #model.add(Dense(32, activation = 'relu'))
    #model.add(Dropout(0.5))

    model.add(Dense(no_of_classes, activation = 'softmax'))

    model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')
    return(model)

# %%
model = model_training(no_of_classes,sampling_rate)
history = model.fit(x_train_tr, y_train_arr, batch_size=64, epochs=30, validation_data=(x_val_tr, y_val_arr))
# Out:
# Epoch 1/30
# 75/75 [==============================] - 1s 4ms/step - loss: 1.3160 - accuracy: 0.5906 - val_loss: 0.3020 - val_accuracy: 0.9525
# Epoch 2/30
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2071 - accuracy: 0.9716 - val_loss: 0.1624 - val_accuracy: 0.9625
# Epoch 3/30
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1158 - accuracy: 0.9765 - val_loss: 0.1294 - val_accuracy: 0.9642
# Epoch 4/30
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0871 - accuracy: 0.9788 - val_loss: 0.1093 - val_accuracy: 0.9700
# Epoch 5/30
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0708 - accuracy: 0.9834 - val_loss: 0.0975 - val_accuracy: 0.9708
# Epoch 6/30
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0627 - accuracy: 0.9841 - val_loss: 0.0937 - val_accuracy: 0.9750
# Epoch 7/30
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0619 - accuracy: 0.9836 - val_loss: 0.0894 - val_accuracy: 0.9750
# Epoch 8/30
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0555 - accuracy: 0.9832 - val_loss: 0.0855 - val_accuracy: 0.9733
# Epoch 9/30
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0511 - accuracy: 0.9836 - val_loss: 0.0779 - val_accuracy: 0.9750
# Epoch 10/30
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0409 - accuracy: 0.9889 - val_loss: 0.0737 - val_accuracy: 0.9758
# Epoch 11/30
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0402 - accuracy: 0.9883 - val_loss: 0.0847 - val_accuracy: 0.9733
# Epoch 12/30
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0335 - accuracy: 0.9924 - val_loss: 0.0703 - val_accuracy: 0.9767
# Epoch 13/30
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0309 - accuracy: 0.9912 - val_loss: 0.0741 - val_accuracy: 0.9758
# Epoch 14/30
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0259 - accuracy: 0.9925 - val_loss: 0.0709 - val_accuracy: 0.9767
# Epoch 15/30
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0255 - accuracy: 0.9938 - val_loss: 0.0679 - val_accuracy: 0.9758
# Epoch 16/30
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0208 - accuracy: 0.9962 - val_loss: 0.0708 - val_accuracy: 0.9750
# Epoch 17/30
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0223 - accuracy: 0.9945 - val_loss: 0.0713 - val_accuracy: 0.9758
# Epoch 18/30
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0209 - accuracy: 0.9941 - val_loss: 0.0697 - val_accuracy: 0.9750
# Epoch 19/30
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0199 - accuracy: 0.9946 - val_loss: 0.0670 - val_accuracy: 0.9758
# Epoch 20/30
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0168 - accuracy: 0.9963 - val_loss: 0.0646 - val_accuracy: 0.9775
# Epoch 21/30
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0202 - accuracy: 0.9944 - val_loss: 0.0614 - val_accuracy: 0.9783
# Epoch 22/30
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0133 - accuracy: 0.9976 - val_loss: 0.0665 - val_accuracy: 0.9767
# Epoch 23/30
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0127 - accuracy: 0.9972 - val_loss: 0.0640 - val_accuracy: 0.9783
# Epoch 24/30
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0140 - accuracy: 0.9972 - val_loss: 0.0674 - val_accuracy: 0.9783
# Epoch 25/30
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0102 - accuracy: 0.9982 - val_loss: 0.0596 - val_accuracy: 0.9825
# Epoch 26/30
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0106 - accuracy: 0.9980 - val_loss: 0.0657 - val_accuracy: 0.9792
# Epoch 27/30
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0086 - accuracy: 0.9987 - val_loss: 0.0633 - val_accuracy: 0.9783
# Epoch 28/30
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0090 - accuracy: 0.9986 - val_loss: 0.0792 - val_accuracy: 0.9733
# Epoch 29/30
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0103 - accuracy: 0.9973 - val_loss: 0.0793 - val_accuracy: 0.9750
# Epoch 30/30
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0083 - accuracy: 0.9991 - val_loss: 0.0647 - val_accuracy: 0.9808

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dense_5 (Dense)              (None, 6)                 390
# =================================================================
# Total params: 16,838
# Trainable params: 16,838
# Non-trainable params: 0
# _________________________________________________________________

# %%
pred_acc = model.evaluate(x_test_tr,y_test_arr)
print("Test accuracy is {}".format(pred_acc))
# Out:
# 113/113 [==============================] - 0s 2ms/step - loss: 0.0529 - accuracy: 0.9800
# Test accuracy is [0.05286566540598869, 0.9799944162368774]

# %%
model.save("model1.h5")
